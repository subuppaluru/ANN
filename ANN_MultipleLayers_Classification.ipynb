# %%
# Artificial Neural Network

# Installing Theano
# pip install --upgrade --no-deps git+git://github.com/Theano/Theano.git

# Installing Tensorflow
# pip install tensorflow

# Installing Keras
# pip install --upgrade keras

# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
X[0:5]
# Out:
# array([[619, 'France', 'Female', 42, 2, 0.0, 1, 1, 1, 101348.88],
#        [608, 'Spain', 'Female', 41, 1, 83807.86, 1, 0, 1, 112542.58],
#        [502, 'France', 'Female', 42, 8, 159660.8, 3, 1, 0, 113931.57],
#        [699, 'France', 'Female', 39, 1, 0.0, 2, 0, 0, 93826.63],
#        [850, 'Spain', 'Female', 43, 2, 125510.82, 1, 1, 1, 79084.1]],
#       dtype=object)

# %%
X.shape
# Out:
# (10000, 10)

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

# %%
X.shape
# Out:
# (10000, 10)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (8000, 10) (8000,)

# %%
X_train[0:5]
# Out:
# array([[667, 2, 0, 34, 5, 0.0, 2, 1, 0, 163830.64],
#        [427, 1, 1, 42, 1, 75681.52, 1, 1, 1, 57098.0],
#        [535, 0, 0, 29, 2, 112367.34, 1, 1, 0, 185630.76],
#        [654, 2, 1, 40, 5, 105683.63, 1, 1, 0, 173617.09],
#        [850, 2, 0, 57, 8, 126776.3, 2, 1, 1, 132298.49]], dtype=object)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (8000, 10) (2000, 10)

# %% [markdown]
# #Using Only Input and Output Layers

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
#classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# Adding the second hidden layer
#classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 4s 3ms/step - loss: 0.5872 - accuracy: 0.7824
# Epoch 2/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4837 - accuracy: 0.8064
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4518 - accuracy: 0.8056
# Epoch 4/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4418 - accuracy: 0.8055
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4384 - accuracy: 0.8069
# Epoch 6/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4373 - accuracy: 0.8080
# Epoch 7/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4370 - accuracy: 0.8077
# Epoch 8/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4369 - accuracy: 0.8080
# Epoch 9/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8074
# Epoch 10/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8080
# Epoch 13/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8100
# Epoch 14/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8080
# Epoch 15/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8067
# Epoch 16/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8085
# Epoch 17/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 18/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 19/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8086
# Epoch 20/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8089
# Epoch 21/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8077
# Epoch 22/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8090
# Epoch 23/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8076
# Epoch 24/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8104
# Epoch 25/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8084
# Epoch 26/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8076
# Epoch 27/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8080
# Epoch 28/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8086
# Epoch 29/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 30/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 31/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8080
# Epoch 32/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8071
# Epoch 33/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8099
# Epoch 34/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8080
# Epoch 35/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8091
# Epoch 36/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8083
# Epoch 37/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8086
# Epoch 38/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8090
# Epoch 39/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8091
# Epoch 40/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8083
# Epoch 41/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8067
# Epoch 43/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8085
# Epoch 44/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 45/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8096
# Epoch 46/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 47/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8077
# Epoch 48/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8095
# Epoch 49/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8079
# Epoch 50/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8076
# Epoch 51/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8080
# Epoch 52/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8086
# Epoch 53/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8086
# Epoch 54/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 55/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8076
# Epoch 56/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8075
# Epoch 57/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8089
# Epoch 58/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8087
# Epoch 59/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8084
# Epoch 60/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8083
# Epoch 61/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 62/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 63/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 64/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8090
# Epoch 65/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8096
# Epoch 66/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8073
# Epoch 67/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8089
# Epoch 68/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8089
# Epoch 69/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 70/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8085
# Epoch 71/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8077
# Epoch 72/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8075
# Epoch 73/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 74/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8098
# Epoch 75/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 76/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8092
# Epoch 77/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8073
# Epoch 78/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8096
# Epoch 79/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8085
# Epoch 80/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8079
# Epoch 81/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8087
# Epoch 82/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8087
# Epoch 83/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8080
# Epoch 84/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8085
# Epoch 85/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8091
# Epoch 86/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 87/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8079
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8095
# Epoch 89/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8086
# Epoch 90/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8081
# Epoch 92/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8092
# Epoch 93/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8084
# Epoch 94/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4368 - accuracy: 0.8077
# Epoch 95/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8079
# Epoch 96/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8096
# Epoch 97/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8076
# Epoch 98/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8086
# Epoch 99/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8084
# Epoch 100/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8095

# %%
import warnings
warnings.filterwarnings("ignore")

# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix \n")
print(cm)
print("\n")
# classification report for precision, recall f1-score and accuracy
from sklearn.metrics import classification_report
matrix = classification_report(y_test,y_pred)
print('Classification report : \n',matrix)
# Out:
# Confusion Matrix
#
# [[1542   53]
#  [ 334   71]]
#
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      1595
#            1       0.57      0.18      0.27       405
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.57      0.58      2000
# weighted avg       0.77      0.81      0.76      2000

# %% [markdown]
# #Using Input , One Hidden Layer and Output Layers

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# Adding the second hidden layer
#classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4987 - accuracy: 0.7955
# Epoch 2/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4294 - accuracy: 0.8112
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4240 - accuracy: 0.8267
# Epoch 4/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4199 - accuracy: 0.8313
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4163 - accuracy: 0.8331
# Epoch 6/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4142 - accuracy: 0.8341
# Epoch 7/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4131 - accuracy: 0.8346
# Epoch 8/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4117 - accuracy: 0.8313
# Epoch 9/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4110 - accuracy: 0.8335
# Epoch 10/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4111 - accuracy: 0.8341
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4102 - accuracy: 0.8340
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4104 - accuracy: 0.8339
# Epoch 13/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4097 - accuracy: 0.8345
# Epoch 14/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4094 - accuracy: 0.8345
# Epoch 15/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4092 - accuracy: 0.8324
# Epoch 16/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4094 - accuracy: 0.8347
# Epoch 17/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4091 - accuracy: 0.8339
# Epoch 18/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4092 - accuracy: 0.8350
# Epoch 19/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4092 - accuracy: 0.8341
# Epoch 20/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4088 - accuracy: 0.8345
# Epoch 21/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4088 - accuracy: 0.8334
# Epoch 22/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4087 - accuracy: 0.8346
# Epoch 23/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4085 - accuracy: 0.8354
# Epoch 24/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4083 - accuracy: 0.8349
# Epoch 25/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4084 - accuracy: 0.8344
# Epoch 26/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4079 - accuracy: 0.8347
# Epoch 27/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4082 - accuracy: 0.8340
# Epoch 28/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4082 - accuracy: 0.8339
# Epoch 29/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4080 - accuracy: 0.8342
# Epoch 30/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4078 - accuracy: 0.8353
# Epoch 31/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4075 - accuracy: 0.8338
# Epoch 32/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4076 - accuracy: 0.8360
# Epoch 33/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4073 - accuracy: 0.8335
# Epoch 34/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4071 - accuracy: 0.8347
# Epoch 35/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4068 - accuracy: 0.8340
# Epoch 36/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4064 - accuracy: 0.8354
# Epoch 37/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4063 - accuracy: 0.8347
# Epoch 38/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4056 - accuracy: 0.8342
# Epoch 39/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4053 - accuracy: 0.8347
# Epoch 40/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4049 - accuracy: 0.8341
# Epoch 41/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4049 - accuracy: 0.8345
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4043 - accuracy: 0.8335
# Epoch 43/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4042 - accuracy: 0.8341
# Epoch 44/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4038 - accuracy: 0.8338
# Epoch 45/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8353
# Epoch 46/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4039 - accuracy: 0.8359
# Epoch 47/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4036 - accuracy: 0.8350
# Epoch 48/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4036 - accuracy: 0.8347
# Epoch 49/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4034 - accuracy: 0.8359
# Epoch 50/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4031 - accuracy: 0.8341
# Epoch 51/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4031 - accuracy: 0.8359
# Epoch 52/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4029 - accuracy: 0.8345
# Epoch 53/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4029 - accuracy: 0.8359
# Epoch 54/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4030 - accuracy: 0.8359
# Epoch 55/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4026 - accuracy: 0.8346
# Epoch 56/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4030 - accuracy: 0.8361
# Epoch 57/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4025 - accuracy: 0.8363
# Epoch 58/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4027 - accuracy: 0.8353
# Epoch 59/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4026 - accuracy: 0.8351
# Epoch 60/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4024 - accuracy: 0.8350
# Epoch 61/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4024 - accuracy: 0.8353
# Epoch 62/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4022 - accuracy: 0.8354
# Epoch 63/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4020 - accuracy: 0.8347
# Epoch 64/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4020 - accuracy: 0.8351
# Epoch 65/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4021 - accuracy: 0.8356
# Epoch 66/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8354
# Epoch 67/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8354
# Epoch 68/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4019 - accuracy: 0.8366
# Epoch 69/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8366
# Epoch 70/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8328
# Epoch 71/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4016 - accuracy: 0.8354
# Epoch 72/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4016 - accuracy: 0.8349
# Epoch 73/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8363
# Epoch 74/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4011 - accuracy: 0.8350
# Epoch 75/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4020 - accuracy: 0.8339
# Epoch 76/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8351
# Epoch 77/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8342
# Epoch 78/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8347
# Epoch 79/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8351
# Epoch 80/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8359
# Epoch 81/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4016 - accuracy: 0.8351
# Epoch 82/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8363
# Epoch 83/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8367
# Epoch 84/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8347
# Epoch 85/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8364
# Epoch 86/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8356
# Epoch 87/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8359
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8354
# Epoch 89/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4009 - accuracy: 0.8355
# Epoch 90/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4009 - accuracy: 0.8357
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4010 - accuracy: 0.8357
# Epoch 92/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8360
# Epoch 93/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4006 - accuracy: 0.8351
# Epoch 94/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4007 - accuracy: 0.8344
# Epoch 95/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4006 - accuracy: 0.8344
# Epoch 96/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4012 - accuracy: 0.8350
# Epoch 97/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4008 - accuracy: 0.8353
# Epoch 98/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4007 - accuracy: 0.8338
# Epoch 99/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4007 - accuracy: 0.8344
# Epoch 100/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4008 - accuracy: 0.8344

# %%
import warnings
warnings.filterwarnings("ignore")

# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix \n")
print(cm)
print("\n")
# classification report for precision, recall f1-score and accuracy
from sklearn.metrics import classification_report
matrix = classification_report(y_test,y_pred)
print('Classification report : \n',matrix)
# Out:
# Confusion Matrix
#
# [[1539   56]
#  [ 249  156]]
#
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      1595
#            1       0.74      0.39      0.51       405
#
#     accuracy                           0.85      2000
#    macro avg       0.80      0.68      0.71      2000
# weighted avg       0.84      0.85      0.83      2000

# %% [markdown]
# #Using Input , Two Hidden Layers and Output Layers

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4933 - accuracy: 0.7952
# Epoch 2/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4314 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4249 - accuracy: 0.8114
# Epoch 4/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4190 - accuracy: 0.8286
# Epoch 5/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4150 - accuracy: 0.8307
# Epoch 6/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4114 - accuracy: 0.8326
# Epoch 7/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4090 - accuracy: 0.8321
# Epoch 8/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4069 - accuracy: 0.8338
# Epoch 9/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4055 - accuracy: 0.8336
# Epoch 10/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8336
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4023 - accuracy: 0.8349
# Epoch 12/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8349
# Epoch 13/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4004 - accuracy: 0.8345
# Epoch 14/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3993 - accuracy: 0.8341
# Epoch 15/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3988 - accuracy: 0.8347
# Epoch 16/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3987 - accuracy: 0.8356
# Epoch 17/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3980 - accuracy: 0.8342
# Epoch 18/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3979 - accuracy: 0.8341
# Epoch 19/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3975 - accuracy: 0.8354
# Epoch 20/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8350
# Epoch 21/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3968 - accuracy: 0.8356
# Epoch 22/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8341
# Epoch 23/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3963 - accuracy: 0.8347
# Epoch 24/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3965 - accuracy: 0.8353
# Epoch 25/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8350
# Epoch 26/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3963 - accuracy: 0.8360
# Epoch 27/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8359
# Epoch 28/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3958 - accuracy: 0.8347
# Epoch 29/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3962 - accuracy: 0.8363
# Epoch 30/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3950 - accuracy: 0.8385
# Epoch 31/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8363
# Epoch 32/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3953 - accuracy: 0.8366
# Epoch 33/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3951 - accuracy: 0.8370
# Epoch 34/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3954 - accuracy: 0.8365
# Epoch 35/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3948 - accuracy: 0.8380
# Epoch 36/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3951 - accuracy: 0.8369
# Epoch 37/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3953 - accuracy: 0.8370
# Epoch 38/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3951 - accuracy: 0.8361
# Epoch 39/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3948 - accuracy: 0.8369
# Epoch 40/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3945 - accuracy: 0.8372
# Epoch 41/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3942 - accuracy: 0.8385
# Epoch 42/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3945 - accuracy: 0.8376
# Epoch 43/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8374
# Epoch 44/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3947 - accuracy: 0.8367
# Epoch 45/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3943 - accuracy: 0.8390
# Epoch 46/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3933 - accuracy: 0.8379
# Epoch 47/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3940 - accuracy: 0.8370
# Epoch 48/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3933 - accuracy: 0.8376
# Epoch 49/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3926 - accuracy: 0.8390
# Epoch 50/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3914 - accuracy: 0.8393
# Epoch 51/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3900 - accuracy: 0.8389
# Epoch 52/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3886 - accuracy: 0.8395
# Epoch 53/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3866 - accuracy: 0.8393
# Epoch 54/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3852 - accuracy: 0.8403
# Epoch 55/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3830 - accuracy: 0.8391
# Epoch 56/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3816 - accuracy: 0.8409
# Epoch 57/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3807 - accuracy: 0.8382
# Epoch 58/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3791 - accuracy: 0.8391
# Epoch 59/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3788 - accuracy: 0.8403
# Epoch 60/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3775 - accuracy: 0.8418
# Epoch 61/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3771 - accuracy: 0.8413
# Epoch 62/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3766 - accuracy: 0.8401
# Epoch 63/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3758 - accuracy: 0.8426
# Epoch 64/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3747 - accuracy: 0.8420
# Epoch 65/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3744 - accuracy: 0.8422
# Epoch 66/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3743 - accuracy: 0.8406
# Epoch 67/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3732 - accuracy: 0.8424
# Epoch 68/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3720 - accuracy: 0.8422
# Epoch 69/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3697 - accuracy: 0.8460
# Epoch 70/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3683 - accuracy: 0.8447
# Epoch 71/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3659 - accuracy: 0.8474
# Epoch 72/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3632 - accuracy: 0.8481
# Epoch 73/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3600 - accuracy: 0.8501
# Epoch 74/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3560 - accuracy: 0.8533
# Epoch 75/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3549 - accuracy: 0.8550
# Epoch 76/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3536 - accuracy: 0.8556
# Epoch 77/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3511 - accuracy: 0.8545
# Epoch 78/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3503 - accuracy: 0.8566
# Epoch 79/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3486 - accuracy: 0.8589
# Epoch 80/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3480 - accuracy: 0.8562
# Epoch 81/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3479 - accuracy: 0.8581
# Epoch 82/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3460 - accuracy: 0.8568
# Epoch 83/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3455 - accuracy: 0.8591
# Epoch 84/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3460 - accuracy: 0.8574
# Epoch 85/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3445 - accuracy: 0.8584
# Epoch 86/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3437 - accuracy: 0.8589
# Epoch 87/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3444 - accuracy: 0.8620
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3442 - accuracy: 0.8600
# Epoch 89/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3432 - accuracy: 0.8574
# Epoch 90/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3428 - accuracy: 0.8605
# Epoch 91/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3436 - accuracy: 0.8618
# Epoch 92/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3429 - accuracy: 0.8585
# Epoch 93/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3435 - accuracy: 0.8584
# Epoch 94/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3425 - accuracy: 0.8593
# Epoch 95/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3423 - accuracy: 0.8585
# Epoch 96/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3424 - accuracy: 0.8590
# Epoch 97/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3426 - accuracy: 0.8581
# Epoch 98/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3421 - accuracy: 0.8594
# Epoch 99/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3426 - accuracy: 0.8564
# Epoch 100/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3422 - accuracy: 0.8579

# %%
import warnings
warnings.filterwarnings("ignore")

# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix \n")
print(cm)
print("\n")
# classification report for precision, recall f1-score and accuracy
from sklearn.metrics import classification_report
matrix = classification_report(y_test,y_pred)
print('Classification report : \n',matrix)
# Out:
# Confusion Matrix
#
# [[1493  102]
#  [ 177  228]]
#
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1595
#            1       0.69      0.56      0.62       405
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.75      0.77      2000
# weighted avg       0.85      0.86      0.85      2000
